# %%
# !wget https://cfsaipd.media.bublupcdn.com/FisNLRthJ8gxHPYQru4fYw/images/full_007-im-85de22b6-4844-4297-b5df-21765b219eb8.jpg
# Out:
# --2022-03-04 23:27:24--  https://cfsaipd.media.bublupcdn.com/FisNLRthJ8gxHPYQru4fYw/images/full_007-im-85de22b6-4844-4297-b5df-21765b219eb8.jpg
# Resolving cfsaipd.media.bublupcdn.com (cfsaipd.media.bublupcdn.com)... 13.35.95.81, 13.35.95.7, 13.35.95.110, ...
# Connecting to cfsaipd.media.bublupcdn.com (cfsaipd.media.bublupcdn.com)|13.35.95.81|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46012 (45K) [image/jpeg]
# Saving to: ‘full_007-im-85de22b6-4844-4297-b5df-21765b219eb8.jpg’
#
# full_007-im-85de22b 100%[===================>]  44.93K  --.-KB/s    in 0.06s
#
# 2022-03-04 23:27:25 (721 KB/s) - ‘full_007-im-85de22b6-4844-4297-b5df-21765b219eb8.jpg’ saved [46012/46012]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Perro = np.array(plt.imread("full_007-im-85de22b6-4844-4297-b5df-21765b219eb8.jpg"))

# %%
plt.imshow(Perro)

# %%
red = Perro[:,:,0]
green = Perro[:,:,1]
blue = Perro[:,:,2]

# %%
plt.imshow(red)

# %%
plt.imshow(green)

# %%
plt.imshow(blue)

# %%
plt.imshow(red, cmap="gray")
plt.title("Red Dog")
plt.axis("off")
plt.show()

# %%
#Accediendo a la forma de la imagen
Perro.shape
# Out:
# (426, 640, 3)

# %%
#Accediendo al tama;o
Perro.size
# Out:
# 817920

# %%
#Volteando la Imagen
volteo_vertical = np.flipud(Perro)

# %%
plt.imshow(volteo_vertical)

# %%
#Volteando la Imagen
volteo_vertical = np.fliplr(Perro)

# %%
plt.imshow(volteo_vertical)

# %%
import matplotlib.pyplot as plt

# %%
#Analisis de Histograma
plt.hist(red.ravel(),bins=256,color='red')
# Out:
# (array([5.000e+01, 3.000e+00, 2.000e+00, 1.100e+01, 4.000e+00, 2.000e+00,
#         6.000e+00, 7.000e+00, 8.000e+00, 1.100e+01, 1.100e+01, 2.900e+01,
#         1.700e+01, 3.600e+01, 9.500e+01, 8.400e+01, 8.000e+01, 7.900e+01,
#         1.110e+02, 1.100e+02, 1.360e+02, 1.380e+02, 1.760e+02, 2.060e+02,
#         2.370e+02, 2.320e+02, 2.500e+02, 2.570e+02, 2.410e+02, 2.690e+02,
#         3.490e+02, 3.370e+02, 3.300e+02, 3.040e+02, 3.000e+02, 3.030e+02,
#         3.160e+02, 3.450e+02, 3.370e+02, 3.450e+02, 3.030e+02, 3.300e+02,
#         3.690e+02, 3.780e+02, 3.850e+02, 4.070e+02, 4.280e+02, 4.220e+02,
#         4.650e+02, 4.690e+02, 4.910e+02, 4.830e+02, 5.250e+02, 5.070e+02,
#         6.100e+02, 5.650e+02, 7.160e+02, 6.630e+02, 6.920e+02, 7.840e+02,
#         7.620e+02, 7.890e+02, 7.950e+02, 8.150e+02, 8.270e+02, 9.230e+02,
#         8.900e+02, 9.460e+02, 9.340e+02, 9.120e+02, 9.670e+02, 1.023e+03,
#         9.760e+02, 1.096e+03, 1.101e+03, 1.091e+03, 1.051e+03, 1.050e+03,
# ...

# %%
#Analisis de Histograma
plt.hist(blue.ravel(),bins=256,color='blue')
# Out:
# (array([ 471.,   90.,  100.,  107.,  123.,  178.,  210.,  219.,  204.,
#          221.,  216.,  202.,  250.,  258.,  322.,  312.,  406.,  452.,
#          603.,  624.,  746.,  878., 1076., 1303., 1476., 1593., 1812.,
#         1670., 1722., 1716., 1586., 1414., 1333., 1289., 1242., 1136.,
#         1082., 1116., 1054., 1009., 1005.,  998.,  995.,  989., 1043.,
#         1067., 1085., 1017.,  961.,  945.,  994.,  895.,  969.,  956.,
#          996.,  958.,  941.,  921.,  935.,  968.,  954.,  959.,  936.,
#          967.,  962.,  964.,  944.,  901.,  967.,  871.,  833.,  862.,
#          789.,  709.,  737.,  697.,  694.,  740.,  667.,  677.,  687.,
#          676.,  700.,  663.,  645.,  670.,  613.,  597.,  625.,  610.,
#          641.,  619.,  642.,  572.,  581.,  607.,  605.,  642.,  592.,
#          590.,  627.,  573.,  612.,  611.,  634.,  580.,  568.,  579.,
#          578.,  594.,  543.,  610.,  595.,  605.,  575.,  532.,  537.,
# ...

# %%
#Analisis de Histograma
plt.hist(green.ravel(),bins=256,color='green')
# Out:
# (array([  60.,   20.,   15.,   35.,   33.,   55.,   45.,   45.,   52.,
#           56.,   69.,   69.,   96.,  109.,  133.,  176.,  179.,  185.,
#          184.,  195.,  236.,  248.,  292.,  321.,  284.,  326.,  375.,
#          448.,  543.,  610.,  684.,  747.,  764.,  775.,  835.,  919.,
#         1022., 1009., 1092., 1135., 1154., 1145., 1113., 1028., 1045.,
#         1016.,  946.,  938.,  890.,  809.,  761.,  705.,  625.,  628.,
#          625.,  575.,  625.,  621.,  580.,  559.,  614.,  615.,  664.,
#          666.,  631.,  635.,  657.,  655.,  669.,  687.,  658.,  700.,
#          671.,  736.,  772.,  820.,  789.,  773.,  822.,  813.,  824.,
#          802.,  798.,  801.,  770.,  777.,  788.,  830.,  800.,  793.,
#          832.,  757.,  843.,  804.,  797.,  772.,  874.,  766.,  811.,
#          806.,  773.,  850.,  883.,  907.,  842.,  862.,  823.,  868.,
#          836.,  901.,  898.,  939.,  935.,  935.,  939.,  935.,  928.,
# ...

# %%
plt.imshow(np.where(volteo_vertical > 150,255,0))

# %%
plt.imshow(volteo_vertical[:,:,1].T)
